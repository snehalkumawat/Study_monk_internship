# %%
# !pip install Pillow

# %%
  
# import required libraries
import os
import sys
from PIL import Image
  
# define a function for
# compressing an image
def compressMe(file, verbose = False):
    
      # Get the path of the file
    filepath = os.path.join(os.getcwd(), 
                            file)
      
    # open the image
    picture = Image.open("/content/arkadiy-7uSsVEbzKmY-unsplash.jpg")
    picture.save("Compressed_"+file, 
                 "JPEG", 
                 optimize = True, 
                 quality = 10)
    return
  
# Define a main function
def main():
    
    verbose = False
      
    # checks for verbose flag
    if (len(sys.argv)>1):
        
        if (sys.argv[1].lower()=="-v"):
            verbose = True
     # finds current working dir
    cwd = os.getcwd()
  
    formats = ('.jpg', '.jpeg')
      
    # looping through all the files
    # in a current directory
    for file in os.listdir(cwd):
        
        # If the file format is JPG or JPEG
        if os.path.splitext(file)[1].lower() in formats:
            print('compressing', file)
            compressMe(file, verbose)
    print("Done")
  
# Driver code
if __name__ == "__main__":
    main()
# Out:
# compressing arkadiy-7uSsVEbzKmY-unsplash.jpg
# Done

# %%
picture = Image.open("/content/Compressed_arkadiy-7uSsVEbzKmY-unsplash.jpg")
picture
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3024x4032 at 0x7FBCED367550>

# %% [markdown]
# 1.Image compression without size

# %%
# !pip install git+https://github.com/UBC-NLP/EmoNet.git
# Out:
# ...
#   Cloning https://github.com/UBC-NLP/EmoNet.git to /tmp/pip-req-build-uw8v2hh7
#   Running command git clone -q https://github.com/UBC-NLP/EmoNet.git /tmp/pip-req-build-uw8v2hh7
# ...
#      |████████████████████████████████| 4.0 MB 14.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 36.6 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 40.4 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 48.6 MB/s
# ...
#   Created wheel for emonet: filename=emonet-0.1-py3-none-any.whl size=194937964 sha256=00df77ed18893884d0929966126442f3ee632bf601ff84d0bcf2fedb4a0d14d9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6vhw1d09/wheels/6a/c3/b1/0a2b216d68a4ab376faedf2321d1bf8b9d727914debf04230a
# ...
#   Created wheel for happiestfuntokenizing: filename=happiestfuntokenizing-0.0.7-py3-none-any.whl size=6726 sha256=22805d26f01edf84e05d8742f4b2e089776c65659fbd5325006bc005c3a28272
# ...
